# %%
import pandas as pd
import numpy as np
import csvkit as cs
import mysql.connector as con
import pymongo 
import json
# Out:
# C:\Users\nikhi\anaconda3\lib\site-packages\requests_toolbelt\_compat.py:56: DeprecationWarning: 'urllib3.contrib.pyopenssl' module is deprecated and will be removed in a future release of urllib3 2.x. Read more in this issue: https://github.com/urllib3/urllib3/issues/2680

# %%
######Task1
#Q1)Read this dataset in pandas , mysql and mongodb 
fitbit_data=pd.read_csv(r"C:\Users\nikhi\OneDrive\Documents\Ineuron\Datasets\FitBit data.csv")#importing the Data

# %%
type(fitbit_data)#verifying in which type is it
# Out:
# pandas.core.frame.DataFrame

# %%
#converting into the json file to import into Mongo Db

fitbit_data.to_json(r"C:\Users\nikhi\OneDrive\Documents\Ineuron\Datasets\FitBit data.json",orient='records')#

# %%
#Reading the json file
fitbit_json=pd.read_json(r"C:\Users\nikhi\OneDrive\Documents\Ineuron\Datasets\FitBit data.csv")

# %%
#convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
#fitbit=pd.to_DataFrame()

#fitbit_json['ActivityDate1']=pd.Timestamp(fitbit_json['ActivityDate'])

fitbit_json['ActivityDate'] = fitbit_json['ActivityDate'].apply(pd.Timestamp)

# %%
with open(r"C:\Users\nikhi\OneDrive\Documents\Ineuron\Datasets\FitBit data.csv") as file :
    data=json.load(file)

# %%
data.to_json(r"C:\Users\nikhi\OneDrive\Documents\Ineuron\Datasets\JsonDataFitbit.json")

# %%
data=pd.DataFrame(data)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#importing the data into mongo DB

client=pymongo.MongoClient("mongodb+srv://nikhilabommareddy:NikhilaAshok@cluster0.lfzadum.mongodb.net/?retryWrites=true&w=majority")
db=client.test
data_dict=data.to_dict(orient='records')
db=client['fitbit_json']
collection=db['newfitbitdata']
collection.insert_many(data_dict)

# %%
type(data_dict)
# Out:
# list

# %%
#Accessing the data in the Mongo DB
record1= collection.find({"Id":1503960366})

# %%
list1=[ ]
for i in record1:
    list1.append(i)

# %%
list1
# Out:
# [{'_id': ObjectId('64908d82bfeec493d96ba114'),
#   'Id': 1503960366,
#   'ActivityDate': '3/28/2016',
#   'TotalSteps': 13231,
#   'TotalDistance': 8.9300003052,
#   'TrackerDistance': 8.9300003052,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.1900000572,
#   'ModeratelyActiveDistance': 0.7900000215,
#   'LightActiveDistance': 4.9499998093,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 39,
#   'FairlyActiveMinutes': 20,
#   'LightlyActiveMinutes': 224,
#   'SedentaryMinutes': 1080,
#   'Calories': 1932},
#  {'_id': ObjectId('64908d82bfeec493d96ba115'),
#   'Id': 1503960366,
#   'ActivityDate': '3/29/2016',
#   'TotalSteps': 12041,
#   'TotalDistance': 7.8499999046,
#   'TrackerDistance': 7.8499999046,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.1600000858,
#   'ModeratelyActiveDistance': 1.0900000334,
#   'LightActiveDistance': 4.6100001335,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 28,
# ...

# %%
list1=pd.DataFrame(list1)

# %%
fitbit_json
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
fitbit_json['Id'].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
 format(fitbit_json['Id'].unique())
# Out:
# '[1503960366 1624580081 1644430081 1844505072 1927972279 2022484408\n 2026352035 2320127002 2347167796 2873212765 2891001357 3372868164\n 3977333714 4020332650 4057192912 4319703577 4388161847 4445114986\n 4558609924 4702921684 5553957443 5577150313 6117666160 6290855005\n 6391747486 6775888955 6962181067 7007744171 7086361926 8053475328\n 8253242879 8378563200 8583815059 8792009665 8877689391]'

# %%
#grouping by ID and sum of the Calories to know each unique person how much they burnt their Calories
data5=pd.DataFrame(fitbit_json.groupby(['Id'])['Calories'].sum())

# %%
# This will give us the maximum amount of calories burnt person details 
data5[data5['Calories']==data5['Calories'].max()]
# Out:
#             Calories
# Id
# 4020332650     98412

# %%
data[data['Calories']==0 ]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
# Ques 6 . how many of them have not logged there activity find out in terms of number of ids
df6=pd.DataFrame(data[data["LoggedActivitiesDistance"]==0]['Id'].unique(),columns=['Id'])# this is for identifying the Id which has not been logged

# %%
print("{} Length of the Unique Id's".format(len(df6)))# counting the no of uniques Ids which are not logged yet
# Out:
# 35 Length of the Unique Id's

# %%
df7=pd.DataFrame(data.groupby(['Id'])['Calories'].sum())# To know the unique Ids and to sum all the calories that they have been burnt

# %%
df7[df7['Calories']==df7['Calories'].min()]# to know the id which they burnt the minimun calories
# Out:
#             Calories
# Id
# 4388161847     14442

# %%
# to know the healthy persons in the dataset the person needs to burn equal quantity of the intake they were taking 

data['Daily_req']=data['Calories'].apply(lambda x: 'Y' if x>1500  else 'N' )

# %%
data8=pd.DataFrame(data.groupby(['Id'])['Daily_req']).count()

# %%
df8['cnt_y']=pd.DataFrame(data[data['Daily_req']=='y'].groupby(['Id'])['Daily_req'].count())

# %%
data=pd.Dataframe(data[data['Daily_req']=='y']).
# Out:
# Empty DataFrame
# Columns: [Daily_req]
# Index: []

# %%
df10=pd.DataFrame(data.groupby(['Id'])['Calories'].mean()).reset_index()

# %%
df10['RankforhealthyPerson']=df10['Calories'].rank(ascending=False)

# %%
print(df10[df10['RankforhealthyPerson']==3])
#df10.sort_values(by=['RankforhealthyPerson','Id'],inplace=False)
# Out:
#             Id     Calories  RankforhealthyPerson
# 21  5577150313  3300.272727                   3.0

# %%
df11=pd.DataFrame(data[data['Daily_req']=='Y'].groupby(['Id'])['Calories'].max())

# %%
df11['Calories'].round(100 * )
# Out:
#             Calories
# Id
# 1503960366      2154
# 1624580081      1574
# 1644430081      4029
# 1844505072      1971
# 1927972279      2783
# 2022484408      3021
# 2026352035      1583
# 2320127002      2206
# 2347167796      2488
# 2873212765      2257
# 2891001357      4562
# 3372868164      2069
# 3977333714      1783
# 4020332650      4034
# 4057192912      2484
# 4319703577      2341
# 4388161847      1878
# 4445114986      2424
# 4558609924      2235
# 4702921684      3597
# 5553957443      2249
# 5577150313      4430
# 6117666160      2884
# 6290855005      3119
# 6391747486      2442
# 6775888955      4286
# 6962181067      2437
# 7007744171      3086
# 7086361926      2862
# 8053475328      3697
# 8253242879      2162
# 8378563200      4234
# 8583815059      2786
# 8792009665      3004
# 8877689391      4526

# %%
# Out:
# 0      Y
# 1      Y
# 2      Y
# 3      Y
# 4      Y
#       ..
# 452    Y
# 453    Y
# 454    Y
# 455    Y
# 456    N
# Name: Daily_req, Length: 457, dtype: object
